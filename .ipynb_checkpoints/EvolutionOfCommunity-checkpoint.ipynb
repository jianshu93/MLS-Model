# %%
import MLS_evolveCoop as mlse
# %matplotlib notebook
import matplotlib.pyplot as plt

model_par_def = {
                #fixed model parameters
                "sampling" : "sample",
                "maxT"  : 15000., 
                "sampleT": 100.,
                "mu"    : 0.05,
                "B_H"   : 3.,
                "D_H"   : 1./40.,
                #variable model parameters
                "cost" : 0.1,
                "TAU_H" : 100.,
                "n0"    : 1E-3,
                "mig"   : 1E-6,
                "r"     : 1.,
                "K"     : 1E3,
                "sigmaBirth" : 0.2,
                #fixed intial condition
                "NUMGROUP" : 40,  
                "numTypeBins" : 100,
                "meanGamma0" : 0,
                "stdGamma0" : 0.001,
                "N0init" : 1.
        }

# %%
model_par1 = model_par_def.copy()
model_par1['mig'] = 1E-4
Output1, Outputstate1 = mlse.single_run_with_plot(model_par1)
# Out:
# using dt=0.01
# Elapsed time run 1 = 295.81814885139465
# <img src="data:image/png;base64,..." width="640">

# %%
model_par2 = model_par_def.copy()
model_par2['mig'] = 1E-2
Output2, Outputstate2 = mlse.single_run_with_plot(model_par2)
# Out:
# using dt=0.01
# Elapsed time run 1 = 227.73409390449524
# <img src="data:image/png;base64,..." width="640">

# %%
model_par3 = model_par_def.copy()
model_par3['mig'] = 1E-3
model_par3['maxT'] = 25000


Output3, Outputstate3 = mlse.single_run_with_plot(model_par3)
# Out:
# using dt=0.01

# %%
model_par4 = model_par_def
model_par4['K'] = 1E-4
Output4, Outputstate4 = mlse.single_run_with_plot(model_par4)
# Out:
# using dt=0.01
# Elapsed time run 1 = 539.8655331134796
# <img src="data:image/png;base64,..." width="640">

# %%
model_par5 = model_par_def.copy()
model_par5['K'] = 1E4
model_par5['mig'] = 1E-4
Output5, Outputstate5 = mlse.single_run_with_plot(model_par5)
# Out:
# using dt=0.01
# Elapsed time run 1 = 261.56344723701477
# <img src="data:image/png;base64,..." width="640">

# %%
model_par6 = model_par_def.copy()
model_par6['K'] = 5E3
model_par6['mig'] = 1E-4
Output6, Outputstate6 = mlse.single_run_with_plot(model_par6)
# Out:
# using dt=0.01
# Elapsed time run 1 = 250.33446502685547
# <img src="data:image/png;base64,..." width="640">

# %%
model_par7 = model_par_def.copy()
model_par7['K'] = 2E3
model_par7['mig'] = 1E-4
Output7, Outputstate7 = mlse.single_run_with_plot(model_par7)
# Out:
# using dt=0.01
# Elapsed time run 1 = 455.85467314720154
# <img src="data:image/png;base64,..." width="640">

# %%
model_par8 = model_par_def.copy()
model_par8['K'] = 5E3
model_par8['mig'] = 1E-5
Output8, Outputstate8 = mlse.single_run_with_plot(model_par8)
# Out:
# using dt=0.01
# Elapsed time run 1 = 279.0486857891083
# <img src="data:image/png;base64,..." width="640">

# %%
model_par9 = model_par_def.copy()
model_par9['K'] = 10E3
model_par9['mig'] = 1E-4
model_par9['cost'] = 0.01
Output9, Outputstate9 = mlse.single_run_with_plot(model_par9)
# Out:
# using dt=0.01
# Elapsed time run 1 = 414.49608182907104
# <img src="data:image/png;base64,..." width="640">

# %%
model_par10 = model_par_def.copy()
model_par10['K'] = 100E3
model_par10['mig'] = 1E-4
model_par10['cost'] = 0.01
Output10, Outputstate10 = mlse.single_run_with_plot(model_par10)
# Out:
# using dt=0.01
# Elapsed time run 1 = 229.1174430847168
# <img src="data:image/png;base64,..." width="640">

# %%
model_par11 = model_par_def.copy()
model_par11['mig'] = 1E-2
model_par11['cost'] = 0.01
Output11, Outputstate11 = mlse.single_run_with_plot(model_par11)
# Out:
# using dt=0.01
# Elapsed time run 1 = 503.61871576309204
# <img src="data:image/png;base64,..." width="640">

# %%
model_par12 = model_par_def.copy()
model_par12['mig'] = 1E-1
model_par12['cost'] = 0.01
Output12, Outputstate12 = mlse.single_run_with_plot(model_par12)
# Out:
# using dt=0.01
# Elapsed time run 1 = 222.4976840019226
# <img src="data:image/png;base64,..." width="640">
